# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install torch==1.4.0
# !pip install requests==2.22.0
# !pip install boto3==1.11.7
# !pip install numpy==1.17.4
# !pip install tqdm==4.36.1
# !pip install botocore==1.14.7
# !pip install apex==0.9.10dev
# !pip install tensorflow==2.3.1

# %% [markdown]
# # Data Prepareration

# %%
# %cd gdrive/My\ Drive/Colab\ Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/BLANC/code/src/preprocessor

# %%
# !git clone https://github.com/yeonsw/BLANC.git
# Out:
# Cloning into 'BLANC'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 73 (delta 28), reused 68 (delta 24), pack-reused 0
# Unpacking objects: 100% (73/73), done.

# %%
# %cd BLANC
# %cd -
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# %cd BLANC/code/src/preprocessor
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/BLANC/code/src/preprocessor

# %%
# !python split_data.py \
    --source /content/gdrive/MyDrive/Colab\ Notebooks/BLANC/data/naturalQ/train.jsonl.gz \
    --train_output /content/gdrive/MyDrive/Colab\ Notebooks/BLANC/data/naturalQ/train.jsonl \
    --dev_output /content/gdrive/MyDrive/Colab\ Notebooks/BLANC/data/naturalQ/dev.jsonl \
    --data_type mrqa
# Out:
# Set random seed: 1234

# %%
# !gzip "/content/gdrive/MyDrive/Colab Notebooks/BLANC/data/naturalQ/train.jsonl"
# !gzip "/content/gdrive/MyDrive/Colab Notebooks/BLANC/data/naturalQ/dev.jsonl"

# %% [markdown]
# # Train

# %%
# %cd /content
# %cd gdrive/My\ Drive/Colab\ Notebooks/BLANC/code
# Out:
# /content
# /content/gdrive/My Drive/Colab Notebooks/BLANC/code

# %%
# !LABEL=xquad_pretrained_viquad_finetuned_bert_base_multilingual_uncased GEOP=0.7 WINS=2 LMB=0.4 bash run_blanc_viquad.sh
# Out:
# 06/21/2022 14:01:52 - INFO - __main__ - device: cuda, n_gpu: 1, 16-bits training: False
# 06/21/2022 14:01:53 - INFO - __main__ - Namespace(dev_file='../data/ViQuADv1.1/dev_ViQuAD.json', do_eval=True, do_lower_case=False, do_train=True, doc_stride=128, eval_batch_size=16, eval_metric='span_f1', eval_per_epoch=10, eval_test=True, fp16=False, geometric_p=0.7, gradient_accumulation_steps=1, learning_rate=2e-05, lmb=0.4, loss_scale=0, max_answer_length=500, max_query_length=128, max_seq_length=384, model='./checkpoints/xquad1.1/xquad_pretrained_bert_base_multilingual_uncased/1234', n_best_size=20, no_cuda=False, num_train_epochs=3.0, output_dir='./checkpoints/viquad1.1/xquad_pretrained_viquad_finetuned_bert_base_multilingual_uncased/1234', seed=1234, test_file='../data/ViQuADv1.1/test_ViQuAD.json', train_batch_size=4, train_file='../data/ViQuADv1.1/train_ViQuAD.json', train_mode='random_sorted', verbose_logging=False, version_2_with_negative=False, warmup_proportion=0.1, window_size=2)
# ...

# %% [markdown]
# # Test

# %%
# !LABEL=xquad_pretrained_bert_base_multilingual_uncased GEOP=0.7 WINS=2 LMB=0.4 bash run_blanc_viquad_test.sh
